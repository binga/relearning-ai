# %%
import warnings
warnings.filterwarnings("ignore")

import torch

import lovely_tensors as lt
lt.monkey_patch()

# %%
from gliclass import GLiClassModel
from transformers import AutoTokenizer

import gliclass
import transformers

print(f"transformers version: {transformers.__version__}")
# Out:
# transformers version: 4.49.0

# %%
model = GLiClassModel.from_pretrained("knowledgator/gliclass-modern-base-v3.0")
model
# Out:
# GLiClassModel(
#   (model): GLiClassUniEncoder(
#     (text_projector): FeaturesProjector(
#       (linear_1): Linear(in_features=768, out_features=768, bias=True)
#       (act): GELUActivation()
#       (linear_2): Linear(in_features=768, out_features=768, bias=True)
#     )
#     (classes_projector): FeaturesProjector(
#       (linear_1): Linear(in_features=768, out_features=768, bias=True)
#       (act): GELUActivation()
#       (linear_2): Linear(in_features=768, out_features=768, bias=True)
#     )
#     (pooler): FirstTokenPooling1D()
#     (scorer): ScorerDot()
#     (dropout): Dropout(p=0.15, inplace=False)
#     (encoder_model): ModernBertModel(
#       (embeddings): ModernBertEmbeddings(
#         (tok_embeddings): Embedding(50370, 768, padding_idx=50283)
#         (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#       (layers): ModuleList(
#         (0): ModernBertEncoderLayer(
#           (attn_norm): Identity()
#           (attn): ModernBertAttention(
#             (Wqkv): Linear(in_features=768, out_features=2304, bias=False)
#             (rotary_emb): ModernBertRotaryEmbedding()
#             (Wo): Linear(in_features=768, out_features=768, bias=False)
#             (out_drop): Identity()
#           )
#           (mlp_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): ModernBertMLP(
#             (Wi): Linear(in_features=768, out_features=2304, bias=False)
#             (act): GELUActivation()
#             (drop): Dropout(p=0.0, inplace=False)
#             (Wo): Linear(in_features=1152, out_features=768, bias=False)
#           )
#         )
#         (1-21): 21 x ModernBertEncoderLayer(
#           (attn_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): ModernBertAttention(
#             (Wqkv): Linear(in_features=768, out_features=2304, bias=False)
#             (rotary_emb): ModernBertRotaryEmbedding()
#             (Wo): Linear(in_features=768, out_features=768, bias=False)
#             (out_drop): Identity()
#           )
#           (mlp_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): ModernBertMLP(
#             (Wi): Linear(in_features=768, out_features=2304, bias=False)
#             (act): GELUActivation()
#             (drop): Dropout(p=0.0, inplace=False)
#             (Wo): Linear(in_features=1152, out_features=768, bias=False)
#           )
#         )
#       )
#       (final_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#   )
# )

# %%
[l[0] for l in model.named_parameters()]
# Out:
# ['model.logit_scale',
#  'model.text_projector.linear_1.weight',
#  'model.text_projector.linear_1.bias',
#  'model.text_projector.linear_2.weight',
#  'model.text_projector.linear_2.bias',
#  'model.classes_projector.linear_1.weight',
#  'model.classes_projector.linear_1.bias',
#  'model.classes_projector.linear_2.weight',
#  'model.classes_projector.linear_2.bias',
#  'model.encoder_model.embeddings.tok_embeddings.weight',
#  'model.encoder_model.embeddings.norm.weight',
#  'model.encoder_model.layers.0.attn.Wqkv.weight',
#  'model.encoder_model.layers.0.attn.Wo.weight',
#  'model.encoder_model.layers.0.mlp_norm.weight',
#  'model.encoder_model.layers.0.mlp.Wi.weight',
#  'model.encoder_model.layers.0.mlp.Wo.weight',
#  'model.encoder_model.layers.1.attn_norm.weight',
#  'model.encoder_model.layers.1.attn.Wqkv.weight',
#  'model.encoder_model.layers.1.attn.Wo.weight',
#  'model.encoder_model.layers.1.mlp_norm.weight',
#  'model.encoder_model.layers.1.mlp.Wi.weight',
#  'model.encoder_model.layers.1.mlp.Wo.weight',
#  'model.encoder_model.layers.2.attn_norm.weight',
#  'model.encoder_model.layers.2.attn.Wqkv.weight',
#  'model.encoder_model.layers.2.attn.Wo.weight',
#  'model.encoder_model.layers.2.mlp_norm.weight',
#  'model.encoder_model.layers.2.mlp.Wi.weight',
#  'model.encoder_model.layers.2.mlp.Wo.weight',
#  'model.encoder_model.layers.3.attn_norm.weight',
#  'model.encoder_model.layers.3.attn.Wqkv.weight',
#  'model.encoder_model.layers.3.attn.Wo.weight',
#  'model.encoder_model.layers.3.mlp_norm.weight',
#  'model.encoder_model.layers.3.mlp.Wi.weight',
#  'model.encoder_model.layers.3.mlp.Wo.weight',
#  'model.encoder_model.layers.4.attn_norm.weight',
#  'model.encoder_model.layers.4.attn.Wqkv.weight',
#  'model.encoder_model.layers.4.attn.Wo.weight',
#  'model.encoder_model.layers.4.mlp_norm.weight',
#  'model.encoder_model.layers.4.mlp.Wi.weight',
#  'model.encoder_model.layers.4.mlp.Wo.weight',
#  'model.encoder_model.layers.5.attn_norm.weight',
#  'model.encoder_model.layers.5.attn.Wqkv.weight',
#  'model.encoder_model.layers.5.attn.Wo.weight',
#  'model.encoder_model.layers.5.mlp_norm.weight',
#  'model.encoder_model.layers.5.mlp.Wi.weight',
#  'model.encoder_model.layers.5.mlp.Wo.weight',
#  'model.encoder_model.layers.6.attn_norm.weight',
#  'model.encoder_model.layers.6.attn.Wqkv.weight',
#  'model.encoder_model.layers.6.attn.Wo.weight',
#  'model.encoder_model.layers.6.mlp_norm.weight',
#  'model.encoder_model.layers.6.mlp.Wi.weight',
#  'model.encoder_model.layers.6.mlp.Wo.weight',
#  'model.encoder_model.layers.7.attn_norm.weight',
#  'model.encoder_model.layers.7.attn.Wqkv.weight',
#  'model.encoder_model.layers.7.attn.Wo.weight',
#  'model.encoder_model.layers.7.mlp_norm.weight',
#  'model.encoder_model.layers.7.mlp.Wi.weight',
#  'model.encoder_model.layers.7.mlp.Wo.weight',
#  'model.encoder_model.layers.8.attn_norm.weight',
#  'model.encoder_model.layers.8.attn.Wqkv.weight',
#  'model.encoder_model.layers.8.attn.Wo.weight',
#  'model.encoder_model.layers.8.mlp_norm.weight',
#  'model.encoder_model.layers.8.mlp.Wi.weight',
#  'model.encoder_model.layers.8.mlp.Wo.weight',
#  'model.encoder_model.layers.9.attn_norm.weight',
#  'model.encoder_model.layers.9.attn.Wqkv.weight',
#  'model.encoder_model.layers.9.attn.Wo.weight',
#  'model.encoder_model.layers.9.mlp_norm.weight',
#  'model.encoder_model.layers.9.mlp.Wi.weight',
#  'model.encoder_model.layers.9.mlp.Wo.weight',
#  'model.encoder_model.layers.10.attn_norm.weight',
#  'model.encoder_model.layers.10.attn.Wqkv.weight',
#  'model.encoder_model.layers.10.attn.Wo.weight',
#  'model.encoder_model.layers.10.mlp_norm.weight',
#  'model.encoder_model.layers.10.mlp.Wi.weight',
#  'model.encoder_model.layers.10.mlp.Wo.weight',
#  'model.encoder_model.layers.11.attn_norm.weight',
#  'model.encoder_model.layers.11.attn.Wqkv.weight',
#  'model.encoder_model.layers.11.attn.Wo.weight',
#  'model.encoder_model.layers.11.mlp_norm.weight',
#  'model.encoder_model.layers.11.mlp.Wi.weight',
#  'model.encoder_model.layers.11.mlp.Wo.weight',
#  'model.encoder_model.layers.12.attn_norm.weight',
#  'model.encoder_model.layers.12.attn.Wqkv.weight',
#  'model.encoder_model.layers.12.attn.Wo.weight',
#  'model.encoder_model.layers.12.mlp_norm.weight',
#  'model.encoder_model.layers.12.mlp.Wi.weight',
#  'model.encoder_model.layers.12.mlp.Wo.weight',
#  'model.encoder_model.layers.13.attn_norm.weight',
#  'model.encoder_model.layers.13.attn.Wqkv.weight',
#  'model.encoder_model.layers.13.attn.Wo.weight',
#  'model.encoder_model.layers.13.mlp_norm.weight',
#  'model.encoder_model.layers.13.mlp.Wi.weight',
#  'model.encoder_model.layers.13.mlp.Wo.weight',
#  'model.encoder_model.layers.14.attn_norm.weight',
#  'model.encoder_model.layers.14.attn.Wqkv.weight',
#  'model.encoder_model.layers.14.attn.Wo.weight',
#  'model.encoder_model.layers.14.mlp_norm.weight',
#  'model.encoder_model.layers.14.mlp.Wi.weight',
#  'model.encoder_model.layers.14.mlp.Wo.weight',
#  'model.encoder_model.layers.15.attn_norm.weight',
#  'model.encoder_model.layers.15.attn.Wqkv.weight',
#  'model.encoder_model.layers.15.attn.Wo.weight',
#  'model.encoder_model.layers.15.mlp_norm.weight',
#  'model.encoder_model.layers.15.mlp.Wi.weight',
#  'model.encoder_model.layers.15.mlp.Wo.weight',
#  'model.encoder_model.layers.16.attn_norm.weight',
#  'model.encoder_model.layers.16.attn.Wqkv.weight',
#  'model.encoder_model.layers.16.attn.Wo.weight',
#  'model.encoder_model.layers.16.mlp_norm.weight',
#  'model.encoder_model.layers.16.mlp.Wi.weight',
#  'model.encoder_model.layers.16.mlp.Wo.weight',
#  'model.encoder_model.layers.17.attn_norm.weight',
#  'model.encoder_model.layers.17.attn.Wqkv.weight',
#  'model.encoder_model.layers.17.attn.Wo.weight',
#  'model.encoder_model.layers.17.mlp_norm.weight',
#  'model.encoder_model.layers.17.mlp.Wi.weight',
#  'model.encoder_model.layers.17.mlp.Wo.weight',
#  'model.encoder_model.layers.18.attn_norm.weight',
#  'model.encoder_model.layers.18.attn.Wqkv.weight',
#  'model.encoder_model.layers.18.attn.Wo.weight',
#  'model.encoder_model.layers.18.mlp_norm.weight',
#  'model.encoder_model.layers.18.mlp.Wi.weight',
#  'model.encoder_model.layers.18.mlp.Wo.weight',
#  'model.encoder_model.layers.19.attn_norm.weight',
#  'model.encoder_model.layers.19.attn.Wqkv.weight',
#  'model.encoder_model.layers.19.attn.Wo.weight',
#  'model.encoder_model.layers.19.mlp_norm.weight',
#  'model.encoder_model.layers.19.mlp.Wi.weight',
#  'model.encoder_model.layers.19.mlp.Wo.weight',
#  'model.encoder_model.layers.20.attn_norm.weight',
#  'model.encoder_model.layers.20.attn.Wqkv.weight',
#  'model.encoder_model.layers.20.attn.Wo.weight',
#  'model.encoder_model.layers.20.mlp_norm.weight',
#  'model.encoder_model.layers.20.mlp.Wi.weight',
#  'model.encoder_model.layers.20.mlp.Wo.weight',
#  'model.encoder_model.layers.21.attn_norm.weight',
#  'model.encoder_model.layers.21.attn.Wqkv.weight',
#  'model.encoder_model.layers.21.attn.Wo.weight',
#  'model.encoder_model.layers.21.mlp_norm.weight',
#  'model.encoder_model.layers.21.mlp.Wi.weight',
#  'model.encoder_model.layers.21.mlp.Wo.weight',
#  'model.encoder_model.final_norm.weight']

# %%
# Compute number of embedding, attention, and other parameters
embedding_params = 0
attention_params = 0
other_params = 0
for name, param in model.named_parameters():
    lname = name.lower()
    if "embed" in lname:
        embedding_params += param.numel()
    elif "attn" in lname or "attention" in lname:
        attention_params += param.numel()
    else:
        other_params += param.numel()
total_params = embedding_params + attention_params + other_params
print(f"Total parameters: {total_params:,}")
print(f"Embedding parameters: {embedding_params:,} ({embedding_params/total_params*100:.2f}%)")
print(f"Attention parameters: {attention_params:,} ({attention_params/total_params*100:.2f}%)")
print(f"Other parameters: {other_params:,} ({other_params/total_params*100:.2f}%)")
# Out:
# Total parameters: 151,378,177
# Embedding parameters: 38,684,928 (25.56%)
# Attention parameters: 51,920,640 (34.30%)
# Other parameters: 60,772,609 (40.15%)
